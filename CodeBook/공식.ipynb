# %% [markdown]
# # 유클리드호제법
# 두 자연수 A > B에 대하여 R = A % B (나머지) 라고 하자.
# 이 때, A와 B의 최대공약수 = B와 R의 최대공약수 이다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def gcd(a, b):
    if a % b == 0:
        return b
    else:
        return gcd(b, a % b)
    
gcd(192, 162)
# Out:
# 6
